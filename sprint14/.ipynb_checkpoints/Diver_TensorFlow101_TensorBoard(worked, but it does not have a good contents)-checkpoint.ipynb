# %%
import tensorflow as tf
import numpy as np

x_train = np.array([[0,0],[0,1],[1,0],[1,1]])
y_train = np.array([[0],[1],[1],[0]])

x = tf.placeholder(tf.float32, [None,2], name='x')
t = tf.placeholder(tf.float32, [None,1], name='t')

W1 = tf.Variable(tf.truncated_normal([2,2]), name='W1')
b1 = tf.Variable(tf.zeros([2]), name='b1')
h = tf.nn.sigmoid(tf.matmul(x,W1) + b1, name='h')

W2 = tf.Variable(tf.truncated_normal([2,1]), name='W2')
b2 = tf.Variable(tf.zeros([1]), name='b2')
y = tf.nn.sigmoid(tf.matmul(h, W2) + b2, name='y')

with tf.name_scope('cross_entropy'):
  cross_entropy = -tf.reduce_sum(t * tf.log(y) + (1 - t) * tf.log(1 - y))

with tf.name_scope('train'):
  train_step = tf.train.GradientDescentOptimizer(0.1).minimize(cross_entropy)

with tf.name_scope('accuracy_koizumi'):
  correct_prediction = tf.equal(tf.sign(y-0.5),tf.sign(t-0.5))
  accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

sess = tf.Session()
sess.run(tf.global_variables_initializer())

tf.summary.scalar('cross_entropy', cross_entropy)
tf.summary.scalar('accuracy', accuracy)
tf.summary.histogram('weights_h', W1)
tf.summary.histogram('biases_h', b1)
tf.summary.histogram('weights_out', W2)
tf.summary.histogram('biases_out', b2)



writer = tf.summary.FileWriter('XOR', sess.graph)
merged = tf.summary.merge_all()


for epoch in range(6000):
    sess.run(train_step,feed_dict={
        x:x_train,
        t:y_train
    })

    if epoch % 100 == 0:
        acc_val = sess.run(
            accuracy,feed_dict={
                x:x_train,
                t:y_train})
        print ('epoch: %d, Accuracy: %f'
               %(epoch, acc_val))


    summary, loss_val, acc_val = sess.run([merged, cross_entropy, accuracy],feed_dict={
        x:x_train,
        t:y_train
    })
    writer.add_summary(summary, epoch)


classified = correct_prediction.eval(session=sess, feed_dict={
    x:x_train,
    t:y_train
})

prob = y.eval(session=sess,feed_dict={
    x:x_train,
})
# Out:
# /Users/szkhome/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# epoch: 0, Accuracy: 0.500000
# epoch: 100, Accuracy: 0.500000
# epoch: 200, Accuracy: 0.500000
# epoch: 300, Accuracy: 0.500000
# epoch: 400, Accuracy: 0.750000
# epoch: 500, Accuracy: 0.750000
# epoch: 600, Accuracy: 1.000000
# epoch: 700, Accuracy: 1.000000
# epoch: 800, Accuracy: 1.000000
# epoch: 900, Accuracy: 1.000000
# epoch: 1000, Accuracy: 1.000000
# epoch: 1100, Accuracy: 1.000000
# epoch: 1200, Accuracy: 1.000000
# epoch: 1300, Accuracy: 1.000000
# epoch: 1400, Accuracy: 1.000000
# epoch: 1500, Accuracy: 1.000000
# epoch: 1600, Accuracy: 1.000000
# epoch: 1700, Accuracy: 1.000000
# epoch: 1800, Accuracy: 1.000000
# epoch: 1900, Accuracy: 1.000000
# epoch: 2000, Accuracy: 1.000000
# epoch: 2100, Accuracy: 1.000000
# epoch: 2200, Accuracy: 1.000000
# epoch: 2300, Accuracy: 1.000000
# epoch: 2400, Accuracy: 1.000000
# epoch: 2500, Accuracy: 1.000000
# epoch: 2600, Accuracy: 1.000000
# epoch: 2700, Accuracy: 1.000000
# epoch: 2800, Accuracy: 1.000000
# epoch: 2900, Accuracy: 1.000000
# epoch: 3000, Accuracy: 1.000000
# epoch: 3100, Accuracy: 1.000000
# epoch: 3200, Accuracy: 1.000000
# epoch: 3300, Accuracy: 1.000000
# epoch: 3400, Accuracy: 1.000000
# epoch: 3500, Accuracy: 1.000000
# epoch: 3600, Accuracy: 1.000000
# epoch: 3700, Accuracy: 1.000000
# epoch: 3800, Accuracy: 1.000000
# epoch: 3900, Accuracy: 1.000000
# epoch: 4000, Accuracy: 1.000000
# epoch: 4100, Accuracy: 1.000000
# epoch: 4200, Accuracy: 1.000000
# epoch: 4300, Accuracy: 1.000000
# epoch: 4400, Accuracy: 1.000000
# epoch: 4500, Accuracy: 1.000000
# epoch: 4600, Accuracy: 1.000000
# epoch: 4700, Accuracy: 1.000000
# epoch: 4800, Accuracy: 1.000000
# epoch: 4900, Accuracy: 1.000000
# epoch: 5000, Accuracy: 1.000000
# epoch: 5100, Accuracy: 1.000000
# epoch: 5200, Accuracy: 1.000000
# epoch: 5300, Accuracy: 1.000000
# epoch: 5400, Accuracy: 1.000000
# epoch: 5500, Accuracy: 1.000000
# epoch: 5600, Accuracy: 1.000000
# epoch: 5700, Accuracy: 1.000000
# epoch: 5800, Accuracy: 1.000000
# epoch: 5900, Accuracy: 1.000000
